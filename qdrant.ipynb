# %%
# !pip install qdrant-client --quiet

# %%
# Эта часть с bge m3 общая, надо перенести в модуль .py

import torch
from torch import nn
from transformers import AutoTokenizer, AutoModel
from tqdm import tqdm

# Примеры
input_texts = [
    "Когда был спущен на воду первый миноносец «Спокойный»?",
    "Есть ли нефть в Удмуртии?",
    "Спокойный (эсминец)\nЗачислен в списки ВМФ СССР 19 августа 1952 года.",
    "Нефтепоисковые работы в Удмуртии были начаты сразу после Второй мировой войны в 1945 году и продолжаются по сей день. Добыча нефти началась в 1967 году."
]

device = "cuda" if torch.cuda.is_available() else "cpu"

# Загружаем модель и токенизатор
tokenizer = AutoTokenizer.from_pretrained("deepvk/USER-bge-m3", use_fast=True)
model = AutoModel.from_pretrained("deepvk/USER-bge-m3")
model.to(device)
model.eval()

# Включаем TF32 для всех float32 матричных умножений
torch.set_float32_matmul_precision('high')

# Опционально ускоряем на через compile
if hasattr(torch, 'compile'):
    model = torch.compile(model)


def model_encode(input_texts, batch_size = 64):
    all_embeddings = []

    for i in tqdm(range(0, len(input_texts), batch_size), desc="Encoding batches"):
        batch_texts = input_texts[i:i+batch_size]
        
        encoded_input = tokenizer(
            batch_texts,
            padding=True,
            truncation=True,
            return_tensors='pt'
        ).to(device)
        
        attention_mask = encoded_input['attention_mask']

        with torch.no_grad():
            model_output = model(**encoded_input)
            token_embeddings = model_output[0]  # [batch, seq_len, hidden]

            # Mean pooling и маска внимания
            mask = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
            summed = torch.sum(token_embeddings * mask, dim=1)
            summed_mask = torch.clamp(mask.sum(dim=1), min=1e-9)
            embeddings = summed / summed_mask

            # Нормализация
            embeddings = nn.functional.normalize(embeddings, p=2, dim=1)
            all_embeddings.append(embeddings.cpu())

    # Объединяем все батчи
    sentence_embeddings = torch.cat(all_embeddings, dim=0)
    return sentence_embeddings

test = model_encode(input_texts)
test.shape
# Out:
# Encoding batches: 100%|██████████| 1/1 [00:22<00:00, 22.33s/it]
# torch.Size([4, 1024])

# %%
import torch 
import json

# Загрузка эмбс 
embs = torch.load("embeddings.pt")
print(embs.shape) 

# Загрузка чанков (сабсэмпл)
with open("chunks_sub.json", "r", encoding="utf-8") as f:
    chunks = json.load(f)
print(len(chunks))
# Out:
# torch.Size([20000, 1024])
# 20000

# %%
from qdrant_client import QdrantClient
from tqdm import tqdm

# Подключение к Qdrant
# Условно здесь нужен хост, но пока точки будут храниться в RAM
client = QdrantClient(":memory:")

# %%
from qdrant_client.models import VectorParams, PointStruct

# Создаём коллекцию 
client.create_collection(
    collection_name="my_collection",
    vectors_config= VectorParams(size=1024, distance="Cosine")
)
# Out:
# True

# %%
# Объекты

# Пример 
'''
points = [ 
    # Можно передавать метадату, например, ссылку или city
    PointStruct(id=1, vector=[0.05, 0.61, 0.76, 0.74], payload={"city": "Berlin"}),
    PointStruct(id=2, vector=[0.19, 0.81, 0.75, 0.11], payload={"city": "London"}),
    PointStruct(id=3, vector=[0.36, 0.55, 0.47, 0.94], payload={"city": "Moscow"}),
    PointStruct(id=4, vector=[0.18, 0.01, 0.85, 0.80], payload={"city": "New York"}),
] 
'''

# Собираем эмбс в PointStruct
points = [
    PointStruct(id = i, vector = emb.tolist(), payload={"city": "Berlin"})
    for i, emb in tqdm(enumerate(embs))
]

# Добавляем данные
client.upsert(
    collection_name="my_collection",
    wait=True,
    points=points
)
# Out:
# 9016it [00:00, 18120.14it/s]
# 20000it [00:01, 19489.35it/s]
# UpdateResult(operation_id=0, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
# Поиск ближайших векторов

# model_encode работает медленно, нужно ускорять 
# почистить датасет (например, есть дубли)

# Пример эмбса, по которому ищем ближайших соседей
# query_vector = [0.4, 0.5, 0.5, 0.75]

input = 'Легкая женская рубашка, белая'
#input = 'Смартфон Xiaomi, черный, высокопроизводительный, хороший экран'

input_embedded = model_encode([input], batch_size = 1) 

# Убрать ось и превратить в список
query_vector = input_embedded[0].tolist()


# Ищем 20 ближайших векторов
search_result = client.query_points(
    collection_name="my_collection",
    query=query_vector,
    limit=20,
    with_payload=True  # для метаданных
)

found = []

for pt in search_result.points:
    print(f"ID: {pt.id}, Score: {pt.score}, Payload: {pt.payload}")
    found.append(pt.id)
# Out:
# Encoding batches: 100%|██████████| 1/1 [00:20<00:00, 20.69s/it]
# ID: 2632, Score: 0.7714044898794246, Payload: {'city': 'Berlin'}
# ID: 3047, Score: 0.7678803993947425, Payload: {'city': 'Berlin'}
# ID: 17072, Score: 0.7671377734275099, Payload: {'city': 'Berlin'}
# ID: 13658, Score: 0.7671377734275099, Payload: {'city': 'Berlin'}
# ID: 8730, Score: 0.7668255086645352, Payload: {'city': 'Berlin'}
# ID: 4583, Score: 0.7668255086645352, Payload: {'city': 'Berlin'}
# ID: 5648, Score: 0.7646647215912676, Payload: {'city': 'Berlin'}
# ID: 1954, Score: 0.7562074425792121, Payload: {'city': 'Berlin'}
# ID: 3961, Score: 0.7561840128745841, Payload: {'city': 'Berlin'}
# ID: 4564, Score: 0.7538648868568862, Payload: {'city': 'Berlin'}
# ID: 15133, Score: 0.748489626290521, Payload: {'city': 'Berlin'}
# ID: 17970, Score: 0.7479757130549884, Payload: {'city': 'Berlin'}
# ID: 19455, Score: 0.7441119664661353, Payload: {'city': 'Berlin'}
# ID: 12051, Score: 0.7419306280840067, Payload: {'city': 'Berlin'}
# ID: 6694, Score: 0.7410004035450786, Payload: {'city': 'Berlin'}
# ID: 2449, Score: 0.7409629931866342, Payload: {'city': 'Berlin'}
# ID: 3612, Score: 0.738752136977629, Payload: {'city': 'Berlin'}
# ID: 8457, Score: 0.7379302894986413, Payload: {'city': 'Berlin'}
# ID: 15432, Score: 0.737339917425998, Payload: {'city': 'Berlin'}
# ID: 430, Score: 0.7371382725250606, Payload: {'city': 'Berlin'}

# %%
# Отображаем найденные 

for i, idx in enumerate(found):
    print(f'------ Найденный {i + 1}')
    print(chunks[idx])
    print()
# Out:
# ------ Найденный 1
# Название: Блузка женская белая
# Категория: zhenshchinam
# Подкатегория: Блузки и рубашки
# Бренд: By Babur
# Цвет: белый
# Размер: 40
#
# Описание: Элегантная белая блузка рубашка с длинным рукавом. Застежка на пуговицы, на спине кокетка, кружевной воротник. Приталенный силуэт образуется за счет вытачек на спинке. Модель традиционного кроя выглядит сдержанно и строго. Легкая ткань приятна для тела и практична в использовании. Рубашка прекрасно сидит на фигуре. Изящная базовая рубашка в элегантном стиле станет универсальной основой незабываемых образов. Она незаменима для офиса, деловых встреч и официальных мероприятий. Базовая рубашка сочетается с одеждой разного стиля. С юбкой-карандашом и туфлями-лодочками вы сможете создать строгий и сдержанный комплект для работы. С джинсами, уютным кардиганом и кедами получится более расслабленный и непринужденный вариант для отдыха. Эта блузка женская белая с длинным рукавом и кружевами незаменима для вашего гардероба.
#
# ------ Найденный 2
# Название: Блузка женская белая
# Категория: zhenshchinam
# Подкатегория: Офис
# Бренд: By Babur
# Цвет: белый
# Размер: 44
#
# Описание: Элегантная белая блузка рубашка с длинным рукавом. Застежка на пуговицы, на спине кокетка, кружевной воротник. Приталенный силуэт образуется за счет вытачек на спинке. Модель традиционного кроя выглядит сдержанно и строго. Легкая ткань приятна для тела и практична в использовании. Рубашка прекрасно сидит на фигуре. Изящная базовая рубашка в элегантном стиле станет универсальной основой незабываемых образов. Она незаменима для офиса, деловых встреч и официальных мероприятий. Базовая рубашка сочетается с одеждой разного стиля. С юбкой-карандашом и туфлями-лодочками вы сможете создать строгий и сдержанный комплект для работы. С джинсами, уютным кардиганом и кедами получится более расслабленный и непринужденный вариант для отдыха. Эта блузка женская белая с длинным рукавом и кружевами незаменима для вашего гардероба.
#
# ------ Найденный 3
# Название: Блузка женская белая
# Категория: muzhchinam
# Подкатегория: Офис
# Бренд: By Babur
# Цвет: белый
# Размер: 44
#
# Описание: Элегантная белая блузка рубашка с длинным рукавом. Застежка на пуговицы, на спине кокетка, кружевной воротник. Приталенный силуэт образуется за счет вытачек на спинке. Модель традиционного кроя выглядит сдержанно и строго. Легкая ткань приятна для тела и практична в использовании. Рубашка прекрасно сидит на фигуре. Изящная базовая рубашка в элегантном стиле станет универсальной основой незабываемых образов. Она незаменима для офиса, деловых встреч и официальных мероприятий. Базовая рубашка сочетается с одеждой разного стиля. С юбкой-карандашом и туфлями-лодочками вы сможете создать строгий и сдержанный комплект для работы. С джинсами, уютным кардиганом и кедами получится более расслабленный и непринужденный вариант для отдыха. Эта блузка женская белая с длинным рукавом и кружевами незаменима для вашего гардероба.
#
# ------ Найденный 4
# Название: Блузка женская белая
# Категория: muzhchinam
# Подкатегория: Офис
# Бренд: By Babur
# Цвет: белый
# Размер: 44
#
# Описание: Элегантная белая блузка рубашка с длинным рукавом. Застежка на пуговицы, на спине кокетка, кружевной воротник. Приталенный силуэт образуется за счет вытачек на спинке. Модель традиционного кроя выглядит сдержанно и строго. Легкая ткань приятна для тела и практична в использовании. Рубашка прекрасно сидит на фигуре. Изящная базовая рубашка в элегантном стиле станет универсальной основой незабываемых образов. Она незаменима для офиса, деловых встреч и официальных мероприятий. Базовая рубашка сочетается с одеждой разного стиля. С юбкой-карандашом и туфлями-лодочками вы сможете создать строгий и сдержанный комплект для работы. С джинсами, уютным кардиганом и кедами получится более расслабленный и непринужденный вариант для отдыха. Эта блузка женская белая с длинным рукавом и кружевами незаменима для вашего гардероба.
#
# ------ Найденный 5
# Название: Блузка женская белая
# Категория: zhenshchinam
# Подкатегория: Офис
# Бренд: By Babur
# Цвет: белый
# Размер: 48
#
# Описание: Элегантная белая блузка рубашка с длинным рукавом. Застежка на пуговицы, на спине кокетка, кружевной воротник. Приталенный силуэт образуется за счет вытачек на спинке. Модель традиционного кроя выглядит сдержанно и строго. Легкая ткань приятна для тела и практична в использовании. Рубашка прекрасно сидит на фигуре. Изящная базовая рубашка в элегантном стиле станет универсальной основой незабываемых образов. Она незаменима для офиса, деловых встреч и официальных мероприятий. Базовая рубашка сочетается с одеждой разного стиля. С юбкой-карандашом и туфлями-лодочками вы сможете создать строгий и сдержанный комплект для работы. С джинсами, уютным кардиганом и кедами получится более расслабленный и непринужденный вариант для отдыха. Эта блузка женская белая с длинным рукавом и кружевами незаменима для вашего гардероба.
#
# ------ Найденный 6
# Название: Блузка женская белая
# Категория: zhenshchinam
# Подкатегория: Офис
# Бренд: By Babur
# Цвет: белый
# Размер: 48
#
# Описание: Элегантная белая блузка рубашка с длинным рукавом. Застежка на пуговицы, на спине кокетка, кружевной воротник. Приталенный силуэт образуется за счет вытачек на спинке. Модель традиционного кроя выглядит сдержанно и строго. Легкая ткань приятна для тела и практична в использовании. Рубашка прекрасно сидит на фигуре. Изящная базовая рубашка в элегантном стиле станет универсальной основой незабываемых образов. Она незаменима для офиса, деловых встреч и официальных мероприятий. Базовая рубашка сочетается с одеждой разного стиля. С юбкой-карандашом и туфлями-лодочками вы сможете создать строгий и сдержанный комплект для работы. С джинсами, уютным кардиганом и кедами получится более расслабленный и непринужденный вариант для отдыха. Эта блузка женская белая с длинным рукавом и кружевами незаменима для вашего гардероба.
#
# ------ Найденный 7
# Название: Блузка женская белая
# Категория: zhenshchinam
# Подкатегория: Офис
# Бренд: By Babur
# Цвет: белый
# Размер: 50
#
# Описание: Элегантная белая блузка рубашка с длинным рукавом. Застежка на пуговицы, на спине кокетка, кружевной воротник. Приталенный силуэт образуется за счет вытачек на спинке. Модель традиционного кроя выглядит сдержанно и строго. Легкая ткань приятна для тела и практична в использовании. Рубашка прекрасно сидит на фигуре. Изящная базовая рубашка в элегантном стиле станет универсальной основой незабываемых образов. Она незаменима для офиса, деловых встреч и официальных мероприятий. Базовая рубашка сочетается с одеждой разного стиля. С юбкой-карандашом и туфлями-лодочками вы сможете создать строгий и сдержанный комплект для работы. С джинсами, уютным кардиганом и кедами получится более расслабленный и непринужденный вариант для отдыха. Эта блузка женская белая с длинным рукавом и кружевами незаменима для вашего гардероба.
#
# ------ Найденный 8
# Название: Рубашка
# Категория: zhenshchinam
# Подкатегория: Офис
# Бренд: BAWER
# Цвет: белый
# Размер: XXL
#
# Описание: Женская рубашка Bawer, выполненная из хлопка. Отлично подойдет как для офиса, так и для повседневной носки. Ткань очень приятна к телу. Крой приталенный, на спинке и полочках вытачки. Спереди планка с застежкой на пуговицы. Отложной воротник, длинный рукав. Притачной манжет застегивается на две пуговицы. Низ фигурный, без разрезов.
#
# ------ Найденный 9
# Название: Блузка
# Категория: zhenshchinam
# Подкатегория: Блузки и рубашки
# Бренд: Pippinel
# Цвет: белый
# Размер: 48
#
# Описание: Легкая ткань и свободный фасон рубашки это основные детали, благодаря которым изделие дарит полную свободу движений и комфорт. Рубашка застегивается на пуговицы.Короткие рукава обеспечивают обладательнице изделия полную свободу движений и комфорт.Классический фасон и прямой силуэт делают рубашку прекрасным дополнением к любому образу. Она идеально впишется и в деловой образ, и в более комфортный casual.
#
# ------ Найденный 10
# Название: Рубашки
# Категория: zhenshchinam
# Подкатегория: Офис
# Бренд: ТЫСЯЧА СТОЛИЦ
# Цвет: белый
# Размер: XL
#
# Описание: Всем модницам давно известно, что белая рубашка является самым трендовым, любимым и практичным предметом гардероба. Наши белые рубашки - базовая вещь гардероба любой женщины и девушки. Носите в офис с брюками и юбками, для девочек в школу. С джинсами, сарафанами и жакетами в свободное время. Изделие приталенного силуэта за счет нагрудных рельефов и рельефов по спинке. Идеальное решение для классических образов. Детали: отложной воротник, длинный рукав, застежка на пуговицах. Белая блузка больших размеров с 38 размера по 52 размер.  Рубашка женская, рубашка женская белая, женская рубашка, рубашка однотонная, рубашка женская больших размеров, рубашка женская оверсайз (oversize), рубашка женская длинная, рубашка для девочек в школу, собираем детей в школу, рубашка белая в школу первое сентября рубашка для школьников на линейку школьная рубашка белая блузка для школы блузка для девочек в школу
#
# ------ Найденный 11
# Название: Лонгслив женский блузка белая хлопок
# Категория: zhenshchinam
# Подкатегория: Лонгсливы
# Бренд: DANAGE
# Цвет: белый
# Размер: XL
#
# Описание: Женский лонгслив базовый - это тренд года! Футболка поло с длинным рукавом - это женская белая кофта, одежда для йоги и фитнеса, женская домашняя одежда, одежда для школы и даже женская одежда для офиса. Джемпер женский сочетается с любым стилем, спортивный стиль или классический. Можно надеть с брюками юбкой и джинсами. Универсальная базовая женская одежда . Женская кофта белая с длинным рукавом, которую можно надеть под пиджак, на прогулку, на деловую встречу, Женский джемпер выполнен из высококачественного, плотного, мягкого хлопка. Лонгслив женский плотный способен как подчеркнуть все ваши достоинства, так и скрыть все необходимые недостатки! Преимущества нашего товара это качественный трикотаж, насыщенная цветовая гамма, правильный пошив. Качественно пошитый лонгслив это не просто модно, но и максимально комфортно. С нашими лонгсливами вы сможете создавать уникальные образы каждый день.
#
# ------ Найденный 12
# Название: Лонгслив женский блузка белая хлопок
# Категория: muzhchinam
# Подкатегория: Лонгсливы
# Бренд: DANAGE
# Цвет: белый
# Размер: XL
#
# Описание: Женский лонгслив базовый - это тренд года! Футболка поло с длинным рукавом - это женская белая кофта, одежда для йоги и фитнеса, женская домашняя одежда, одежда для школы и даже женская одежда для офиса. Джемпер женский сочетается с любым стилем, спортивный стиль или классический. Можно надеть с брюками юбкой и джинсами. Универсальная базовая женская одежда . Женская кофта белая с длинным рукавом, которую можно надеть под пиджак, на прогулку, на деловую встречу, Женский джемпер выполнен из высококачественного, плотного, мягкого хлопка. Лонгслив женский плотный способен как подчеркнуть все ваши достоинства, так и скрыть все необходимые недостатки! Преимущества нашего товара это качественный трикотаж, насыщенная цветовая гамма, правильный пошив. Качественно пошитый лонгслив это не просто модно, но и максимально комфортно. С нашими лонгсливами вы сможете создавать уникальные образы каждый день.
#
# ------ Найденный 13
# Название:  Рубашка женская белая оверсайз
# Категория: zhenshchinam
# Подкатегория: Блузки и рубашки
# Бренд: Kulibili
# Цвет: белый
# Размер: 48
#
# Описание: Элегантная рубашка женская оверсайз отличный вариант для повседневного выхода на работу. Изделие сзади удлиненное и имеет декоративные пуговицы по длине. Необычный крой модели, сделает ваш силуэт незабываемым. Все что вам нужно для создания гармоничного образа - ваша фантазия. В любой сезон. Осенняя, зимняя, весенняя или летняя погода не помешает вам быть обворожительной в нашей рубашке. В ней вы не будете испытывать чувства скованности и неудобства. Любой выход в ней обеспечит вам неизгладимые впечатления, ведь она приятная на ощупь, стильная, праздничная. Классическая блузка подходит и для школьного варианта одежды. Модель OVERSIZE - это главная тенденция в мире моды. Вы будете в тренде сезона
#
# ------ Найденный 14
# Название: Рубашка женская оверсайз белая
# Категория: muzhchinam
# Подкатегория: Рубашки
# Бренд: Camicia
# Цвет: фиолетовый
# Размер: M
#
# Описание: Без летней трикотажной рубашки с длинным рукавом не обойдется ни один базовый гардероб. Блуза прямого кроя оверсайз станет любимой одеждой девочек подростков, взрослых девушек и даже беременных. Классическая объемная рубаха обладает невероятно большим спектром применение, подойдет для офиса и школы, вечерних весенних прогулок, праздничных мероприятий. Плотная, но легкая хлопковая блузка женская идеально дополнит подростковый и рабочий лук, будет активно использоваться в повседневной жизни не только летом, но и в демисезонный период (осенью и весной). С ней без труда удастся создать модные, красивые луки. Хлопок при этом обеспечит полный комфорт. Мягкая рубашка будет широко востребована у модниц всех возрастов. Данная рубашка невероятно удобная, она не сковывает движения, не сдавливает плечи. В модельном ряде представлено множество вариантов цветов рубашек- белая, бежевая, зеленая, розовая, сиреневая, черная, фуксия. Вы можете купить наши товары по акции, в подарок со скидкой!
#
# ------ Найденный 15
# Название: Рубашка женская оверсайз белая
# Категория: muzhchinam
# Подкатегория: Рубашки
# Бренд: Camicia
# Цвет: черный
# Размер: S
#
# Описание: Без летней трикотажной рубашки с длинным рукавом не обойдется ни один базовый гардероб. Блуза прямого кроя оверсайз станет любимой одеждой девочек подростков, взрослых девушек и даже беременных. Классическая объемная рубаха обладает невероятно большим спектром применение, подойдет для офиса и школы, вечерних весенних прогулок, праздничных мероприятий. Плотная, но легкая хлопковая блузка женская идеально дополнит подростковый и рабочий лук, будет активно использоваться в повседневной жизни не только летом, но и в демисезонный период (осенью и весной). С ней без труда удастся создать модные, красивые луки. Хлопок при этом обеспечит полный комфорт. Мягкая рубашка будет широко востребована у модниц всех возрастов. Данная рубашка невероятно удобная, она не сковывает движения, не сдавливает плечи. В модельном ряде представлено множество вариантов цветов рубашек- белая, бежевая, зеленая, розовая, сиреневая, черная, фуксия. Вы можете купить наши товары по акции, в подарок со скидкой!
#
# ------ Найденный 16
# Название: Костюм женский/шерстяной/вязаный/тёплый/
# Категория: zhenshchinam
# Подкатегория: Для невысоких
# Бренд: ALINA женский костюм вязаные
# Цвет: белый
# Размер: 40-44
#
# Описание: Удобный брючный костюм незаменим в базовом гардеробе современной девушки. Трикотажный костюм выполнен из приятной на ощупь. Благодаря лаконичному крою брюки и худи легко сочетаются как между собой, так и со многими базовыми вещами в гардеробе. Универсальная ростовка подойдет для высоких и для невысоких дам. Костюм вязаный женский подойдет на все случаи жизни: офис, спорт, одежда для дома , для беременных. Спортивный костюм женский также может использоваться как домашний костюм, максимально сделав ваше пребывание дома комфортным. Базовый костюм не вытягивается, не теряет форму после стирки, сохраняет форму на долгие годы.
#
# ------ Найденный 17
# Название: Рубашка Oversize женская оверсайз белая
# Категория: zhenshchinam
# Подкатегория: Для высоких
# Бренд: Darya Selskaya
# Цвет: белый
# Размер: XL
#
# Описание: Женская рубашка. Рубашка из качественного материала в стиле OVERSIZE белого цвета. Тонкий длинноволокнистый хлопок особенно прочный, отлично пропускает воздух и впитывает влагу,что делает его идеальным выбором для любого гардероба. Свободная и удлиненная женская рубашка оверсайз, позволяет с легкостью скрыть недостатки фигуры и подчёркнуть её достоинства. Она дополнит любой ваш образ с шортами и короткими топами, легинсами, джинсами, брюками и юбками. А также рубашку можно носить как блузку, или же носить как второй слой поверх футболки или топа. Если вам нужна блузка для офиса, блузка на новый год, блузка вечерняя или также рубашка на новый год, то эта белая базовая и черная рубашки будут идеальными вариантами вашего гардероба. на 1 сентября женская оверсайз летняя хлопок, классическая рубашка, рубашка женская в клетку, белая рубашка, черная рубашка, чёрная рубашка, джинсовая рубашка женская, льняная рубашка женская, рубашка-платье, розовая рубашка с коротким рукавом с длинным рукавом
#
# ------ Найденный 18
# Название: Рубашка Oversize женская оверсайз белая
# Категория: premium-store
# Подкатегория: Женщинам
# Бренд: Darya Selskaya
# Цвет: белый
# Размер: XS
#
# Описание: Женская рубашка. Рубашка из качественного материала в стиле OVERSIZE белого цвета. Тонкий длинноволокнистый хлопок особенно прочный, отлично пропускает воздух и впитывает влагу,что делает его идеальным выбором для любого гардероба. Свободная и удлиненная женская рубашка оверсайз, позволяет с легкостью скрыть недостатки фигуры и подчёркнуть её достоинства. Она дополнит любой ваш образ с шортами и короткими топами, легинсами, джинсами, брюками и юбками. А также рубашку можно носить как блузку, или же носить как второй слой поверх футболки или топа. Если вам нужна блузка для офиса, блузка на новый год, блузка вечерняя или также рубашка на новый год, то эта белая базовая и черная рубашки будут идеальными вариантами вашего гардероба. на 1 сентября женская оверсайз летняя хлопок, классическая рубашка, рубашка женская в клетку, белая рубашка, черная рубашка, чёрная рубашка, джинсовая рубашка женская, льняная рубашка женская, рубашка-платье, розовая рубашка с коротким рукавом с длинным рукавом
#
# ------ Найденный 19
# Название: Рубашка Oversize женская оверсайз белая
# Категория: muzhchinam
# Подкатегория: Большие размеры
# Бренд: Darya Selskaya
# Цвет: белый
# Размер: XL
#
# Описание: Женская рубашка. Рубашка из качественного материала в стиле OVERSIZE белого цвета. Тонкий длинноволокнистый хлопок особенно прочный, отлично пропускает воздух и впитывает влагу,что делает его идеальным выбором для любого гардероба. Свободная и удлиненная женская рубашка оверсайз, позволяет с легкостью скрыть недостатки фигуры и подчёркнуть её достоинства. Она дополнит любой ваш образ с шортами и короткими топами, легинсами, джинсами, брюками и юбками. А также рубашку можно носить как блузку, или же носить как второй слой поверх футболки или топа. Если вам нужна блузка для офиса, блузка на новый год, блузка вечерняя или также рубашка на новый год, то эта белая базовая и черная рубашки будут идеальными вариантами вашего гардероба. на 1 сентября женская оверсайз летняя хлопок, классическая рубашка, рубашка женская в клетку, белая рубашка, черная рубашка, чёрная рубашка, джинсовая рубашка женская, льняная рубашка женская, рубашка-платье, розовая рубашка с коротким рукавом с длинным рукавом
#
# ------ Найденный 20
# Название: Костюм женский/шерстяной/вязаный/тёплый/
# Категория: zhenshchinam
# Подкатегория: Для невысоких
# Бренд: ALINA женский костюм вязаные
# Цвет: белый
# Размер: oversize
#
# Описание: Удобный брючный костюм незаменим в базовом гардеробе современной девушки. Трикотажный костюм выполнен из приятной на ощупь. Благодаря лаконичному крою брюки и худи легко сочетаются как между собой, так и со многими базовыми вещами в гардеробе. Универсальная ростовка подойдет для высоких и для невысоких дам. Костюм вязаный женский подойдет на все случаи жизни: офис, спорт, одежда для дома , для беременных. Спортивный костюм женский также может использоваться как домашний костюм, максимально сделав ваше пребывание дома комфортным. Базовый костюм не вытягивается, не теряет форму после стирки, сохраняет форму на долгие годы.
